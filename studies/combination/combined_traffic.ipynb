# %% [markdown]
# # Combine traffic data in similar format

# %%
from glob import glob
import sets
import datetime
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd
import numpy as np
# Out:
# /Users/along528/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: DeprecationWarning: the sets module is deprecated
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Illinois traffic data

# %%
dbname = 'traffic_stops_il'
username = 'along528'
pswd = 'password'
con_il = None
con_il = psycopg2.connect(database = dbname, user = username, host='localhost', password=pswd)

# %%
for year in range(2004,2015):
    for race in ['black','white']:
        query = """
        SELECT agencycode,agencyname,count(agencycode) AS stops_<RACE>,
        SUM(CASE WHEN searchconducted = 'Yes' THEN 1 ELSE 0 END) as searches_<RACE>,
        SUM(CASE WHEN contrabandfound = 'Yes' THEN 1 ELSE 0 END) as hits_<RACE>,
        year 
        FROM traffic_stops_<YEAR>
        WHERE race = '<RACE>'
        GROUP BY agencycode,agencyname,year
        """
        query = query.replace('<RACE>',race)
        query = query.replace('<YEAR>',str(year))
        print query
        break

# %%
pd.read_sql(query,con_il)
# Out:
#      agencycode                                         agencyname  \
# 0         10011                                      Dolton Police
# 1         12987                      South Suburban College Police
# 2         12988                               South Holland Police
# 3         12989                       South Chicago Heights Police
# 4         12990                                      Skokie Police
# 5         12991                               Schiller Park Police
# 6         12992                                  Schaumburg Police
# 7         12993                                Sauk Village Police
# 8         12994                                    Rosemont Police
# 9         12995                             Rolling Meadows Police
# 10        12996                                     Robbins Police
# 11        12997                                   Riverside Police
# 12        12998                                   Riverdale Police
# 13        12999                                 River Grove Police
# 14        13000                                River Forest Police
# 15        13001                                Richton Park Police
# 16        13002                            Prospect Heights Police
# 17        13003                                       Posen Police
# 18        13004                                     Phoenix Police
# 19        13005                                  Park Ridge Police
# 20        13006                                 Park Forest Police
# 21        13007                                  Palos Park Police
# 22        13008                                 Palos Hills Police
# 23        13009                               Palos Heights Police
# 24        13010                                    Palatine Police
# 25        13011                                 Orland Park Police
# 26        13012                              Olympia Fields Police
# 27        13013                    Oakton Community College Police
# 28        13014                                    Oak Park Police
# 29        13015                                    Oak Lawn Police
# ..          ...                                                ...
# 799       14057                       University Of Chicago Police
# 800       14059                      Rockford Park District Police
# 801       14061                                      Dowell Police
# 802       14063                                    Waterman Police
# 803       14065                                  Brookfield Police
# 804       14067                                      Worden Police
# 805       14068                               Prairie Grove Police
# 806       14070                                South Beloit Police
# 807       14071                               Milledgeville Police
# 808       14075   Us Veterans Administration Police-Hines Hospital
# 809       14077                                Orland Hills Police
# 810       14078                                    Golconda Police
