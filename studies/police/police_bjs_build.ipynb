# %% [markdown]
# ## Building the Police BJS Database

# %%
## Python packages - you may have to pip install sqlalchemy, sqlalchemy_utils, and psycopg2.
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd

# %%
#In Python: Define a database name (we're using a dataset on births, so I call it 
# birth_db), and your username for your computer (CHANGE IT BELOW). 
dbname = 'police_bjs'
username = 'along528'
pswd = 'password'
## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print engine.url
# Replace localhost with IP address if accessing a remote server
# Out:
# postgresql://along528:password@localhost/police_bjs

# %%
## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
# load a database from CSV
police_csv  = '/Users/along528/Dropbox/insight/project/datasets/police/ICPSR_31161/DS0001/31161-0001-Data.csv'
police_data = pd.DataFrame.from_csv(police_csv)
police_data.columns = map(str.lower, police_data.columns)
police_data[police_data['state']=='NC']
# Out:
#          formtype resptype  agcytype                           agency  \
# SURVEYID
# 592             L     full         5      NORTHCAROLINASTATEHWYPATROL
# 570             L     full         3  CHARLOTTE-MECKLENBURGPOLICEDEPT
# 589             L     full         3     JACKSONVILLEPOLICEDEPARTMENT
# 2127            S     full         3     HOLLYSPRINGSPOLICEDEPARTMENT
# 571             L     full         3          CONCORDPOLICEDEPARTMENT
# 583             L     full         3       GREENVILLEPOLICEDEPARTMENT
# 2165            S     full         3         SURFCITYPOLICEDEPARTMENT
# 581             L     full         3        GOLDSBOROPOLICEDEPARTMENT
# 2157            S     full         3       ROCKINGHAMPOLICEDEPARTMENT
# 2141            S     full         3         MINTHILLPOLICEDEPARTMENT
# 2154            S     full         3          PILOTMOUNTAINPOLICEDEPT
# 602             L     full         3    WINSTON-SALEMPOLICEDEPARTMENT
# 576             L     full         3     FAYETTEVILLEPOLICEDEPARTMENT
# 565             L     full         3       BURLINGTONPOLICEDEPARTMENT
# 2142            S     full         3                 MONROEPOLICEDEPT
# 2158            S     full         3        SALISBURYPOLICEDEPARTMENT
# 600             L     full         3             WILMINGTONPOLICEDEPT
# 2148            S     full         3           MURPHYPOLICEDEPARTMENT
# 580             L     full         3         GASTONIAPOLICEDEPARTMENT
# 582             L     full         3       GREENSBOROPOLICEDEPARTMENT
# 587             L     full         3              HIGHPOINTPOLICEDEPT
# 567             L     full         3             CARYPOLICEDEPARTMENT
# 575             L     full         3           DURHAMPOLICEDEPARTMENT
# 594             L     full         3                RALEIGHPOLICEDEPT
# 569             L     full         3       CHAPELHILLPOLICEDEPARTMENT
# 601             L     full         3           WILSONPOLICEDEPARTMENT
# 563             L     full         3        ASHEVILLEPOLICEDEPARTMENT
# 596             L     full         3       ROCKYMOUNTPOLICEDEPARTMENT
# 578             L     full         3           GASTONCOUNTYPOLICEDEPT
# 2145            S     full         3      MORRISVILLEPOLICEDEPARTMENT
# ...           ...      ...       ...                              ...
# 574             L     full         1       DURHAMCOUNTYSHERIFFSOFFICE
# 598             L     full         1        UNIONCOUNTYSHERIFFSOFFICE
# 584             L     full         1     GUILFORDCOUNTYSHERIFFSOFFICE
# 593             L     full         1         PITTCOUNTYSHERIFFSOFFICE
# 585             L     full         1    HENDERSONCOUNTYSHERIFFSOFFICE
# 588             L     full         1      IREDELLCOUNTYSHERIFFSOFFICE
# 573             L     full         1     DAVIDSONCOUNTYSHERIFFSOFFICE
# 591             L     full         1        NEWHANOVERCOUNTYSHERIFF'S
# 566             L     full         1     CABARRUSCOUNTYSHERIFFSOFFICE
# 599             L     full         1        WAKECOUNTYSHERIFF'SOFFICE
# 2152            S     full         1      ORANGECOUNTYSHERIFF'SOFFICE
# 2172            S     full         1        WARRENCOUNTYSHERIFFOFFICE
# 2163            S     full         1       STANLYCOUNTYSHERIFFSOFFICE
# 2123            S     full         1      HALIFAXCOUNTYSHERIFFSOFFICE
# 2153            S     full         1       PENDERCOUNTYSHERIFFSOFFICE
# 2096            S     full         1     BEAUFORTCOUNTYSHERIFFSOFFICE
# 2106            S     full         1            CARTERETCOUNTYSHERIFF
# 2143            S     full         1        MOORECOUNTYSHERIFFSOFFICE
# 595             L     full         1     RANDOLPHCOUNTYSHERIFFSOFFICE
# 2104            S     full         1       CAMDENCOUNTYSHERIFFSOFFICE
# 562             L     full         1    ALAMANCECOUNTYSHERIFF'SOFFICE
# 577             L     full         1      FORSYTHCOUNTYSHERIFFSOFFICE
# 2159            S     full         1     SCOTLANDCOUNTYSHERIFFSOFFICE
# 2115            S     full         1    CURRITUCKCOUNTYSHERIFFSOFFICE
# 2098            S     full         1       BERTIECOUNTYSHERIFFSOFFICE
# 2108            S     full         1      CHATHAMCOUNTYSHERIFFSOFFICE
# 2151            S     full         1       ONSLOWCOUNTYSHERIFFSOFFICE
# 2173            S     full         1    WASHINGTONCOUNTYSHERIFFOFFICE
# 2116            S     full         1        DUPLINCOUNTYSHERIFFOFFICE
# 2122            S     full         1              GRAHAMCOUNTYSHERIFF
#
#                     city state zipcode swnauthemp  swnftemp  swnptemp  \
# SURVEYID
# 592              Raleigh    NC   27611       1823      1718         0
# 570            Charlotte    NC   28202       1628      1481         0
# 589         Jacksonville    NC   28541        111       107         1
# 2127        HollySprings    NC   27540         36        36         5
# 571              Concord    NC   28026        150       148         0
# 583           Greenville    NC   27835        170       170         0
# 2165            SurfCity    NC   28445         17        17         1
# 581            Goldsboro    NC   27533        112       107         0
# 2157          Rockingham    NC   28380         35        35         0
# 2141            MintHill    NC   28227         28        28         0
# 2154       PilotMountain    NC   27041          8         8         6
# 602         WinstonSalem    NC   27101        514       500         0
# 576         Fayetteville    NC   28301        364       342         2
# 565           Burlington    NC   27216        114       105         0
# 2142              Monroe    NC   28111         84        79         0
# 2158           Salisbury    NC   28145         88        82         0
# 600           Wilmington    NC   28402        259       250         0
# 2148              Murphy    NC   28906         10         9         0
# 580             Gastonia    NC   28053        167       165         0
# 582           Greensboro    NC   27402        592       557         7
# 587            HighPoint    NC   27260        225       220         0
# 567                 Cary    NC   27512        165       156         0
# 575               Durham    NC   27701        500       508         0
# 594              Raleigh    NC   27602        764       710         0
# 569           ChapelHill    NC   27514        118       115        10
# 601               Wilson    NC   27894        114       114         0
# 563            Asheville    NC   28802        205       193         5
# 596           RockyMount    NC   27802        160       133        10
# 578             Gastonia    NC   28053        137       133         0
# 2145         Morrisville    NC   27560         36        25         0
# ...                  ...   ...     ...        ...       ...       ...
# 574               Durham    NC   27702        164       163         1
# 598               Monroe    NC   28112        168       164         0
# 584           Greensboro    NC   27402        244       244         0
# 593           Greenville    NC   27835        269       119        20
# 585       Hendersonville    NC   28792        124       124        44
# 588          Statesville    NC   28687        156       156        27
# 573            Lexington    NC   27293        128       128        30
# 591           Wilmington    NC   28401        280       280        30
# 566              Concord    NC   28026        197       197         0
# 599              Raleigh    NC   27602        340       340         0
# 2152        Hillsborough    NC   27278         90        90        10
# 2172           Warrenton    NC   27589         32        30         4
# 2163           Albemarle    NC   28001         45        45         5
# 2123             Halifax    NC   27839         50        50         5
# 2153              Burgaw    NC   28425         53        47         6
# 2096          Washington    NC   27889         51        44         5
# 2106            Beaufort    NC   28516         46        46        19
# 2143            Carthage    NC   28327         85        75        10
# 595             Asheboro    NC   27205        218       155         3
# 2104              Camden    NC   27921         17        17         2
# 562               Graham    NC   27253        120       120         5
# 577         WinstonSalem    NC   27120        238       238        18
# 2159          Laurinburg    NC   28353         38        36         3
# 2115           Currituck    NC   27929         54        54         1
# 2098             Windsor    NC   27983         25        18         5
# 2108           Pittsboro    NC   27312         73        73         4
# 2151        Jacksonville    NC   28540        125       125        12
# 2173            Plymouth    NC   27962         25        25         0
# 2116         Kenansville    NC   28349         70        70         4
# 2122        Robbinsville    NC   28771         13        13         1
#
#                ...         impgangtask  imphumntask  impterrtask  impcell  \
# SURVEYID       ...
# 592            ...                 NaN          NaN          NaN      NaN
# 570            ...                 NaN          NaN          NaN      NaN
# 589            ...                 NaN          NaN          NaN      NaN
# 2127           ...                 NaN          NaN          NaN      NaN
# 571            ...             1.05914          NaN          NaN      NaN
# 583            ...                 NaN          NaN          NaN      NaN
# 2165           ...                 NaN          NaN          NaN      NaN
# 581            ...                 NaN          NaN          NaN      NaN
# 2157           ...                 NaN          NaN          NaN      NaN
# 2141           ...                 NaN          NaN          NaN      NaN
# 2154           ...                 NaN          NaN          NaN      NaN
# 602            ...             1.04973      1.05914          NaN      NaN
# 576            ...             NC02601     10037999       167157      100
# 565            ...             1.05914          NaN          NaN      NaN
# 2142           ...                 NaN          NaN          NaN      NaN
# 2158           ...                 NaN          NaN          NaN      NaN
# 600            ...             1.05914          NaN          NaN      NaN
# 2148           ...                 NaN          NaN          NaN      NaN
# 580            ...                 NaN          NaN          NaN      NaN
# 582            ...             1.05914          NaN          NaN      NaN
# 587            ...                 NaN          NaN          NaN      NaN
# 567            ...             1.04973      1.05914          NaN      NaN
# 575            ...                 NaN          NaN          NaN      NaN
# 594            ...             1.05914          NaN          NaN      NaN
# 569            ...                 NaN          NaN          NaN      NaN
# 601            ...             1.04973      1.05914          NaN      NaN
# 563            ...             1.04973      1.05914          NaN      NaN
# 596            ...             1.05914          NaN          NaN      NaN
# 578            ...             1.05914          NaN          NaN      NaN
# 2145           ...                 NaN          NaN          NaN      NaN
# ...            ...                 ...          ...          ...      ...
# 574            ...                 NaN          NaN          NaN      NaN
# 598            ...                 NaN          NaN          NaN      NaN
# 584            ...                 NaN          NaN          NaN      NaN
# 593            ...                 NaN          NaN          NaN      NaN
# 585            ...                 NaN          NaN          NaN      NaN
# 588            ...                 NaN          NaN          NaN      NaN
# 573            ...                 NaN          NaN          NaN      NaN
# 591            ...                 NaN          NaN          NaN      NaN
# 566            ...                 NaN          NaN          NaN      NaN
# 599            ...                 NaN          NaN          NaN      NaN
# 2152           ...                 NaN          NaN          NaN      NaN
# 2172           ...                 NaN          NaN          NaN      NaN
# 2163           ...                 NaN          NaN          NaN      NaN
# 2123           ...                 NaN          NaN          NaN      NaN
# 2153           ...                 NaN          NaN          NaN      NaN
# 2096           ...                 NaN          NaN          NaN      NaN
# 2106           ...                 NaN          NaN          NaN      NaN
# 2143           ...                 NaN          NaN          NaN      NaN
# 595            ...                 NaN          NaN          NaN      NaN
# 2104           ...                 NaN          NaN          NaN      NaN
# 562            ...                 NaN          NaN          NaN      NaN
# 577            ...                 NaN          NaN          NaN      NaN
# 2159           ...                 NaN          NaN          NaN      NaN
# 2115           ...                 NaN          NaN          NaN      NaN
# 2098           ...                 NaN          NaN          NaN      NaN
# 2108           ...                 NaN          NaN          NaN      NaN
# 2151           ...                 NaN          NaN          NaN      NaN
# 2173           ...                 NaN          NaN          NaN      NaN
# 2116           ...                 NaN          NaN          NaN      NaN
# 2122           ...                 NaN          NaN          NaN      NaN
#
#               ori  csllea04_id  population  lpdsampgrp  finalwt_page1  \
# SURVEYID
# 592           NaN          NaN         NaN         NaN            NaN
# 570           NaN          NaN         NaN         NaN            NaN
# 589           NaN          NaN         NaN         NaN            NaN
# 2127          NaN          NaN         NaN         NaN            NaN
# 571           NaN          NaN         NaN         NaN            NaN
# 583           NaN          NaN         NaN         NaN            NaN
# 2165          NaN          NaN         NaN         NaN            NaN
# 581           NaN          NaN         NaN         NaN            NaN
# 2157          NaN          NaN         NaN         NaN            NaN
# 2141          NaN          NaN         NaN         NaN            NaN
# 2154          NaN          NaN         NaN         NaN            NaN
# 602           NaN          NaN         NaN         NaN            NaN
# 576       1.04973      1.05914         NaN         NaN            NaN
# 565           NaN          NaN         NaN         NaN            NaN
# 2142          NaN          NaN         NaN         NaN            NaN
# 2158          NaN          NaN         NaN         NaN            NaN
# 600           NaN          NaN         NaN         NaN            NaN
# 2148          NaN          NaN         NaN         NaN            NaN
# 580           NaN          NaN         NaN         NaN            NaN
# 582           NaN          NaN         NaN         NaN            NaN
# 587           NaN          NaN         NaN         NaN            NaN
# 567           NaN          NaN         NaN         NaN            NaN
# 575           NaN          NaN         NaN         NaN            NaN
# 594           NaN          NaN         NaN         NaN            NaN
# 569           NaN          NaN         NaN         NaN            NaN
# 601           NaN          NaN         NaN         NaN            NaN
# 563           NaN          NaN         NaN         NaN            NaN
# 596           NaN          NaN         NaN         NaN            NaN
# 578           NaN          NaN         NaN         NaN            NaN
# 2145          NaN          NaN         NaN         NaN            NaN
# ...           ...          ...         ...         ...            ...
# 574           NaN          NaN         NaN         NaN            NaN
# 598           NaN          NaN         NaN         NaN            NaN
# 584           NaN          NaN         NaN         NaN            NaN
# 593           NaN          NaN         NaN         NaN            NaN
# 585           NaN          NaN         NaN         NaN            NaN
# 588           NaN          NaN         NaN         NaN            NaN
# 573           NaN          NaN         NaN         NaN            NaN
# 591           NaN          NaN         NaN         NaN            NaN
# 566           NaN          NaN         NaN         NaN            NaN
# 599           NaN          NaN         NaN         NaN            NaN
# 2152          NaN          NaN         NaN         NaN            NaN
# 2172          NaN          NaN         NaN         NaN            NaN
# 2163          NaN          NaN         NaN         NaN            NaN
# 2123          NaN          NaN         NaN         NaN            NaN
# 2153          NaN          NaN         NaN         NaN            NaN
# 2096          NaN          NaN         NaN         NaN            NaN
# 2106          NaN          NaN         NaN         NaN            NaN
# 2143          NaN          NaN         NaN         NaN            NaN
# 595           NaN          NaN         NaN         NaN            NaN
# 2104          NaN          NaN         NaN         NaN            NaN
# 562           NaN          NaN         NaN         NaN            NaN
# 577           NaN          NaN         NaN         NaN            NaN
# 2159          NaN          NaN         NaN         NaN            NaN
# 2115          NaN          NaN         NaN         NaN            NaN
# 2098          NaN          NaN         NaN         NaN            NaN
# 2108          NaN          NaN         NaN         NaN            NaN
# 2151          NaN          NaN         NaN         NaN            NaN
# 2173          NaN          NaN         NaN         NaN            NaN
# 2116          NaN          NaN         NaN         NaN            NaN
# 2122          NaN          NaN         NaN         NaN            NaN
#
#           finalwt_page2on
# SURVEYID
# 592                   NaN
# 570                   NaN
# 589                   NaN
# 2127                  NaN
# 571                   NaN
# 583                   NaN
# 2165                  NaN
# 581                   NaN
# 2157                  NaN
# 2141                  NaN
# 2154                  NaN
# 602                   NaN
# 576                   NaN
# 565                   NaN
# 2142                  NaN
# 2158                  NaN
# 600                   NaN
# 2148                  NaN
# 580                   NaN
# 582                   NaN
# 587                   NaN
# 567                   NaN
# 575                   NaN
# 594                   NaN
# 569                   NaN
# 601                   NaN
# 563                   NaN
# 596                   NaN
# 578                   NaN
# 2145                  NaN
# ...                   ...
# 574                   NaN
# 598                   NaN
# 584                   NaN
# 593                   NaN
# 585                   NaN
# 588                   NaN
# 573                   NaN
# 591                   NaN
# 566                   NaN
# 599                   NaN
# 2152                  NaN
# 2172                  NaN
# 2163                  NaN
# 2123                  NaN
# 2153                  NaN
# 2096                  NaN
# 2106                  NaN
# 2143                  NaN
# 595                   NaN
# 2104                  NaN
# 562                   NaN
# 577                   NaN
# 2159                  NaN
# 2115                  NaN
# 2098                  NaN
# 2108                  NaN
# 2151                  NaN
# 2173                  NaN
# 2116                  NaN
# 2122                  NaN
#
# [112 rows x 384 columns]

# %%
police_data.to_sql('police_data_table', engine, if_exists='replace')
